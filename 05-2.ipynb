# %%
import gdown

gdown.download('https://bit.ly/3pK7iuu', 'ns_book7.csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3pK7iuu
# To: /Users/yunseokgyu/study/school-class/ml-vocational-class/ns_book7.csv
# 100%|██████████| 53.8M/53.8M [00:03<00:00, 16.9MB/s]
# 'ns_book7.csv'

# %%
import pandas as pd

ns_book7 = pd.read_csv('ns_book7.csv', low_memory=False)
ns_book7.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
count_by_year = ns_book7['발행년도'].value_counts()
count_by_year
# Out:
# 2012    18601
# 2014    17797
# 2009    17611
# 2011    17523
# 2010    17503
#         ...
# 2650        1
# 2108        1
# 2104        1
# 2560        1
# 1947        1
# Name: 발행년도, Length: 87, dtype: int64

# %%
count_by_year = count_by_year.sort_index()
count_by_year
# Out:
# 1947     1
# 1948     1
# 1949     1
# 1952    11
# 1954     1
#         ..
# 2551     1
# 2552     2
# 2559     1
# 2560     1
# 2650     1
# Name: 발행년도, Length: 87, dtype: int64

# %%
count_by_year = count_by_year[count_by_year.index <= 2030]
count_by_year
# Out:
# 1947        1
# 1948        1
# 1949        1
# 1952       11
# 1954        1
#         ...
# 2020    11834
# 2021     1255
# 2025        1
# 2028        1
# 2030        1
# Name: 발행년도, Length: 68, dtype: int64

# %%
import numpy as np

def kdc_1st_char(no):
    if no is np.nan:
        return '-1'
    else:
        return no[0]

count_by_subject = ns_book7['주제분류번호'].apply(kdc_1st_char).value_counts()
count_by_subject
# Out:
# 8     108643
# 3      80767
# 5      40916
# 9      26375
# 6      25070
# 1      22647
# -1     16978
# 7      15836
# 4      13688
# 2      13474
# 0      12376
# Name: 주제분류번호, dtype: int64

# %%
ns_book7.loc[~ns_book7['주제분류번호'].isna()]
# Out:
#             번호                  도서명                        저자    출판사  발행년도  \
# 30          31               적자의 본질        스테파니 켈튼 지음, 이가영 옮김  비즈니스맵  2021
# 31          32     한 권으로 배우는 음악 이야기                    전기홍 지음   상상출판  2021
# 32          33                인간 관찰       구라하시 마야코 지음, 황세정 옮김  쌤앤파커스  2021
# 33          34               정원의 쓸모     수 스튜어트 스미스 지음, 고정아 옮김     윌북  2021
# 34          35  뇌는 당신이 왜 우울한지 알고 있다  야오나이린 지음, 정세경 옮김, 전홍진 감수   더퀘스트  2021
# ...        ...                  ...                       ...    ...   ...
# 376765  401674          소설의 사회사 비교론                    조동일 지음  지식산업사  2001
# 376766  401677                  큰오빠                    박정근 지음  우리문학사  1998
# 376767  401678              韓國現代詩大系                    채만묵 編著  한국문화사  1996
# 376768  401679                뉴 웨이브                제임스 모나코 지음    한나래  1996
# 376769  401681         독일 문학과 세계 문학                    吳漢鎭 編著     벽호  1995
#
#                  ISBN        세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 30      9788986022292            NaN  NaN  NaN   327.04     1     1
# 31      9791190938617            NaN  NaN  NaN    670.4     1     1
# 32      9791165343125            NaN  NaN  NaN    189.2     1     1
# 33      9791155813478            NaN  NaN  NaN    525.3     1     1
# 34      9791165214821            NaN  NaN  NaN    181.3     1     1
# ...               ...            ...  ...  ...      ...   ...   ...
# 376765  9788942340262  9788942300365  NaN    3    809.3     1     0
# 376766  9788974231323  9788974231309  NaN    2    813.6     2     0
# 376767  9788977352971  9788977352988  NaN    3  811.608     1     0
# 376768  9788985367448  9788985367424  NaN    2   688.04     1     0
# 376769  9788947700368  9788947700405  NaN    3   809.05     2     0
#
#               등록일자
# 30      2021-03-16
# 31      2021-03-16
# 32      2021-03-16
# 33      2021-03-16
# 34      2021-03-16
# ...            ...
# 376765  1970-01-01
# 376766  1970-01-01
# 376767  1970-01-01
# 376768  1970-01-01
# 376769  1970-01-01
#
# [359792 rows x 13 columns]

# %%
import matplotlib.pylab as plt

plt.rcParams['figure.dpi'] = 100

plt.plot(count_by_year.index, count_by_year.values)
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.show()

# %%
plt.plot(count_by_year, marker='.', linestyle=':', color='red')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.show()

# %%
plt.plot(count_by_year, '.:r')

# %%
plt.plot(count_by_year, '*-g')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.show()

# %%
plt.plot(count_by_year, '*-g')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
    plt.annotate(val, (idx, val))
plt.show()

# %%
plt.plot(count_by_year, '*-g')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
    plt.annotate(val, (idx, val), xytext=(idx+1, val+10))
plt.show()

# %%
plt.plot(count_by_year, '*-g')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
    plt.annotate(val, (idx, val), xytext=(2, 2), textcoords='offset points')
plt.show()

# %%
plt.bar(count_by_subject.index, count_by_subject.values)
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
for idx, val in count_by_subject.items():
    plt.annotate(val, (idx, val), xytext=(0, 2), textcoords='offset points')
plt.show()

# %%
plt.bar(count_by_subject.index, count_by_subject.values, width=0.7, color='blue')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
for idx, val in count_by_subject.items():
    plt.annotate(val, (idx, val), xytext=(0, 2), textcoords='offset points', fontsize=8, ha='center', color='green')
plt.show()

# %%
plt.barh(count_by_subject.index, count_by_subject.values, height=0.7, color='blue')
plt.title('Books by year')
plt.xlabel('year')
plt.ylabel('number of books')
for idx, val in count_by_subject.items():
    plt.annotate(val, (val, idx), xytext=(0, 2), textcoords='offset points', fontsize=8, va='center', color='green')
plt.show()

# %%
import sys
if 'google.colab' in sys.modules:
    # !wget https://bit.ly/3wrj4xf -O jupiter.png

# %%
gdown.download('https://bit.ly/3wrj4xf', 'jupiter.png', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3wrj4xf
# To: /Users/yunseokgyu/study/school-class/ml-vocational-class/jupiter.png
# 100%|██████████| 3.29M/3.29M [00:00<00:00, 8.95MB/s]
# 'jupiter.png'

# %%
img = plt.imread('jupiter.png')
img.shape
# Out:
# (1561, 1646, 3)

# %%
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from PIL import Image

pil_img = Image.open("jupiter.png")
plt.imshow(pil_img)
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imsave('jupiter.jpg', img)

# %%
plt.rcParams['savefig.dpi']
plt.barh(count_by_subject.index, count_by_subject.values, height=0.7, color='blue')
plt.title('Books by subject')
plt.xlabel('number of books')
plt.ylabel('subject')
for idx, val in count_by_subject.items():
    plt.annotate(val, (val, idx), xytext=(2, 0), textcoords='offset points', fontsize=8, va='center', color='green')
plt.savefig('books_by_subject.png')
plt.show()

# %%
pil_img = Image.open('books_by_subject.png')

plt.figure(figsize=(8, 6))
plt.imshow(pil_img)
plt.axis('off')
plt.show()
